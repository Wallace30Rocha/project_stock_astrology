# %% [markdown]
# ## STOOQ SP500

# %%
import pandas as pd

# %%
file = open(r'C:\Users\PC\Desktop\Ironhack\WR_Ironhack_Projects\Stock&Moon\^spx_d.csv')
sp_df = pd.read_csv(file)
sp_df
# Out:
#              Date     Open     High      Low    Close        Volume
# 0      1789-05-01     0.51     0.51     0.51     0.51           NaN
# 1      1789-06-01     0.51     0.51     0.51     0.51           NaN
# 2      1789-07-01     0.50     0.50     0.50     0.50           NaN
# 3      1789-08-01     0.50     0.51     0.50     0.51           NaN
# 4      1789-09-01     0.51     0.51     0.50     0.51           NaN
# ...           ...      ...      ...      ...      ...           ...
# 38924  2023-04-17  4137.17  4151.72  4123.18  4151.32  2.134208e+09
# 38925  2023-04-18  4164.26  4169.48  4140.36  4154.87  2.125370e+09
# 38926  2023-04-19  4139.33  4162.57  4134.49  4154.52  2.167628e+09
# 38927  2023-04-20  4130.48  4148.57  4114.57  4129.79  2.452867e+09
# 38928  2023-04-21  4132.14  4138.02  4113.86  4133.52  2.297556e+09
#
# [38929 rows x 6 columns]

# %%
#rename columns
sp_df = sp_df.rename(columns = {'Date': 'date', 'Open': 'open', 'High': 'high', 'Low': 'low', 
                                'Close': 'close', 'Volume': 'volume'})

#create a new column with % change from last close to new open
#sp_df['percent_change'] = np.nan
#mask = (sp_df['close'].shift() != np.nan) & (sp_df['open'].notna())
#sp_df.loc[mask, 'percent_change'] = ((sp_df['open'] - sp_df['close'].shift()) / sp_df['close'].shift()) * 100

#crate a new column with the % change
column_values = sp_df['close']
pct_diff = column_values.pct_change() * 100
sp_df['percent_change'] = pct_diff

#realocate the % change column to the sixth spot
sp_df.insert(5, 'percent_change', sp_df.pop('percent_change'))

#crate a new column with the % volume change
column_values = sp_df['volume']
pct_diff = column_values.pct_change() * 100
sp_df['volume_percent_change'] = pct_diff

#eliminate rows with dates prior to 1928
sp_df = sp_df[sp_df['date'] >= '1928-01-01']
sp_df = sp_df.reset_index (drop=True)

#convert NaN to 0
sp_df['percent_change'] = sp_df['percent_change'].fillna(0)
sp_df['date'] = sp_df['date'].fillna(0)
sp_df['open'] = sp_df['open'].fillna(0)
sp_df['high'] = sp_df['high'].fillna(0)
sp_df['low'] = sp_df['low'].fillna(0)
sp_df['close'] = sp_df['close'].fillna(0)
sp_df['percent_change'] = sp_df['percent_change'].fillna(0)
sp_df['volume'] = sp_df['volume'].fillna(0)
sp_df['volume_percent_change'] = sp_df['volume_percent_change'].fillna(0)

# check the number of the rows contain inf values
inf_cols = sp_df.isin([np.inf, -np.inf]).any()
inf_rows = sp_df.isin([np.inf, -np.inf]).any(axis=1)
# print the columns and rows containing inf values
print("Rows containing inf: ", list(inf_rows[inf_rows == True].index))

#treat inf values
inf_df = sp_df.isin([np.inf, -np.inf])
inf_rows = sp_df.loc[inf_df.any(axis=1)]
print(inf_rows)
print(sp_df.iloc[6492])
sp_df = sp_df.replace([np.inf, -np.inf], 0)
# Out:
# Rows containing inf:  []
# Empty DataFrame
# Columns: [date, open, high, low, close, percent_change, volume, volume_percent_change]
# Index: []
# date                     1950-01-03
# open                          16.66
# high                          16.66
# low                           16.66
# close                         16.66
# percent_change            -0.596659
# volume                     700000.0
# volume_percent_change           0.0
# Name: 6492, dtype: object

# %%
sp_df.tail(50)
# Out:
#              date     open     high      low    close  percent_change  \
# 24974  2023-02-09  4144.25  4156.23  4069.67  4081.50       -0.882983
# 24975  2023-02-10  4068.92  4094.36  4060.79  4090.46        0.219527
# 24976  2023-02-13  4096.62  4138.90  4092.67  4137.29        1.144859
# 24977  2023-02-14  4126.70  4159.77  4095.01  4136.13       -0.028038
# 24978  2023-02-15  4119.50  4148.11  4103.98  4147.60        0.277312
# 24979  2023-02-16  4114.75  4136.54  4089.49  4090.41       -1.378870
# 24980  2023-02-17  4077.39  4081.51  4047.95  4079.09       -0.276745
# 24981  2023-02-21  4052.35  4052.35  3995.19  3997.34       -2.004123
# 24982  2023-02-22  4001.83  4017.37  3976.90  3991.05       -0.157355
# 24983  2023-02-23  4018.60  4028.30  3969.19  4012.32        0.532942
# 24984  2023-02-24  3973.24  3978.25  3943.08  3970.04       -1.053754
# 24985  2023-02-27  3992.36  4018.05  3973.55  3982.24        0.307302
# 24986  2023-02-28  3977.19  3997.50  3968.98  3970.15       -0.303598
# 24987  2023-03-01  3963.34  3971.73  3939.05  3951.39       -0.472526
# 24988  2023-03-02  3938.68  3990.84  3928.16  3981.35        0.758214
# 24989  2023-03-03  3998.02  4048.29  3995.17  4045.64        1.614779
# 24990  2023-03-06  4055.15  4078.49  4044.61  4048.42        0.068716
# 24991  2023-03-07  4048.26  4050.00  3980.31  3986.37       -1.532697
# 24992  2023-03-08  3987.55  4000.41  3969.76  3992.01        0.141482
# 24993  2023-03-09  3998.66  4017.81  3908.70  3918.32       -1.845937
# 24994  2023-03-10  3912.77  3934.05  3846.32  3861.59       -1.447814
# 24995  2023-03-13  3835.12  3905.05  3808.86  3855.76       -0.150974
# 24996  2023-03-14  3894.01  3937.29  3873.63  3919.29        1.647665
# 24997  2023-03-15  3876.74  3894.26  3838.24  3891.93       -0.698086
# 24998  2023-03-16  3878.93  3964.46  3864.11  3960.28        1.756198
# 24999  2023-03-17  3958.69  3958.91  3901.27  3916.64       -1.101942
# 25000  2023-03-20  3917.47  3956.62  3916.89  3951.57        0.891836
# 25001  2023-03-21  3975.89  4009.08  3971.19  4002.87        1.298218
# 25002  2023-03-22  4002.04  4039.49  3936.17  3936.97       -1.646319
# 25003  2023-03-23  3959.21  4007.66  3919.05  3948.72        0.298453
# 25004  2023-03-24  3939.21  3972.74  3909.16  3970.99        0.563980
# 25005  2023-03-27  3982.93  4003.83  3970.49  3977.53        0.164694
# 25006  2023-03-28  3974.13  3979.20  3951.53  3971.27       -0.157384
# 25007  2023-03-29  3999.53  4030.59  3999.53  4027.81        1.423726
# 25008  2023-03-30  4046.74  4057.85  4032.10  4050.83        0.571526
# 25009  2023-03-31  4056.18  4110.75  4056.18  4109.31        1.443655
# 25010  2023-04-03  4102.20  4127.66  4098.79  4124.51        0.369892
# 25011  2023-04-04  4128.03  4133.13  4086.87  4100.60       -0.579705
# 25012  2023-04-05  4094.50  4099.69  4072.56  4090.38       -0.249232
# 25013  2023-04-06  4081.15  4107.32  4069.84  4105.02        0.357913
# 25014  2023-04-10  4085.20  4109.50  4072.55  4109.11        0.099634
# 25015  2023-04-11  4110.29  4124.26  4102.61  4108.94       -0.004137
# 25016  2023-04-12  4121.72  4134.37  4086.94  4091.95       -0.413489
# 25017  2023-04-13  4100.04  4150.26  4099.40  4146.22        1.326263
# 25018  2023-04-14  4140.11  4163.19  4113.20  4137.64       -0.206935
# 25019  2023-04-17  4137.17  4151.72  4123.18  4151.32        0.330623
# 25020  2023-04-18  4164.26  4169.48  4140.36  4154.87        0.085515
# 25021  2023-04-19  4139.33  4162.57  4134.49  4154.52       -0.008424
# 25022  2023-04-20  4130.48  4148.57  4114.57  4129.79       -0.595255
# 25023  2023-04-21  4132.14  4138.02  4113.86  4133.52        0.090319
#
#              volume  volume_percent_change
# 24974  2.664805e+09               3.977576
# 24975  2.311051e+09             -13.275044
# 24976  2.125294e+09              -8.037751
# 24977  2.220641e+09               4.486282
# 24978  2.124554e+09              -4.326995
# 24979  2.270678e+09               6.877884
# 24980  2.399670e+09               5.680752
# 24981  2.364297e+09              -1.474095
# 24982  2.271027e+09              -3.944903
# 24983  2.316029e+09               1.981569
# 24984  2.185600e+09              -5.631578
# 24985  2.074395e+09              -5.088097
# 24986  2.776248e+09              33.834104
# 24987  2.234880e+09             -19.499992
# 24988  2.252768e+09               0.800421
# 24989  2.232453e+09              -0.901776
# 24990  2.189914e+09              -1.905513
# 24991  2.279769e+09               4.103130
# 24992  2.040747e+09             -10.484484
# 24993  2.610567e+09              27.922165
# 24994  3.224150e+09              23.503790
# 24995  3.998506e+09              24.017383
# 24996  3.434042e+09             -14.116875
# 24997  3.692413e+09               7.523817
# 24998  3.620889e+09              -1.937051
# 24999  5.743241e+09              58.614124
# 25000  2.958330e+09             -48.490235
# 25001  2.998269e+09               1.350060
# 25002  2.722934e+09              -9.183137
# 25003  2.821296e+09               3.612341
# 25004  2.609180e+09              -7.518393
# 25005  2.462252e+09              -5.631170
# 25006  1.993130e+09             -19.052584
# 25007  2.265665e+09              13.673745
# 25008  2.136728e+09              -5.690908
# 25009  2.525401e+09              18.190071
# 25010  2.427596e+09              -3.872822
# 25011  2.263558e+09              -6.757231
# 25012  2.329609e+09               2.918020
# 25013  2.074707e+09             -10.941834
# 25014  1.951642e+09              -5.931704
# 25015  2.000949e+09               2.526462
# 25016  2.249009e+09              12.397114
# 25017  2.198579e+09              -2.242308
# 25018  2.089949e+09              -4.940953
# 25019  2.134208e+09               2.117729
# 25020  2.125370e+09              -0.414113
# 25021  2.167628e+09               1.988244
# 25022  2.452867e+09              13.159058
# 25023  2.297556e+09              -6.331798

# %%
sp_df.to_csv(r'C:\Users\PC\Desktop\Ironhack\WR_Ironhack_Projects\Stock&Moon\sp500_index.csv', index = False)
